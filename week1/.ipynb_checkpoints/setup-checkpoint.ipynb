# %%
import pandas as pd, numpy as np, matplotlib, sklearn
print(pd.__version__, np.__version__, matplotlib.__version__, sklearn.__version__)
# Out:
# 2.3.3 2.2.5 3.10.9 1.7.2

# %%
import pandas as pd
data = {"Nama": ["Ani", "Budi", "Citra"], "Nilai": [85, 90, 88]}
df = pd.DataFrame(data)
df
# Out:
#     Nama  Nilai
# 0    Ani     85
# 1   Budi     90
# 2  Citra     88

# %%
import matplotlib.pyplot as plt
plt.bar(df["Nama"], df["Nilai"])
plt.title("Nilai Mahasiswa")
plt.show()

# %% [markdown]
# Environment setup selesai, semua library utama sudah terpasang dan diuji.
