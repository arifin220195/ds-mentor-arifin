# %% [markdown]
# import pandas as pd
#
# data = {
#     "Nama" : ["A", "B", "C", "D"],
#     "Kelas" : [2, 3, 4, 5],
#     "Nilai" : [80, 85, 90, 95]
#
# }

# %%
print(data)
# Out:
# {'Nama': ['A', 'B', 'C', 'D'], 'Kelas': [2, 3, 4, 5], 'Nilai': [80, 85, 90, 95]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Nama  Kelas  Nilai
# 0    A      2     80
# 1    B      3     85
# 2    C      4     90
# 3    D      5     95

# %%
print('Menampilkan head \n')
df.head()
# Out:
# Menampilkan head
#   Nama  Kelas  Nilai
# 0    A      2     80
# 1    B      3     85
# 2    C      4     90
# 3    D      5     95

# %%
print('Menampilkan describe \n')
df.describe()
# Out:
# Menampilkan describe
#           Kelas      Nilai
# count  4.000000   4.000000
# mean   3.500000  87.500000
# std    1.290994   6.454972
# min    2.000000  80.000000
# 25%    2.750000  83.750000
# 50%    3.500000  87.500000
# 75%    4.250000  91.250000
# max    5.000000  95.000000

# %%
print('Menampilkan info \n')
df.info()
# Out:
# Menampilkan info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    4 non-null      object
#  1   Kelas   4 non-null      int64
#  2   Nilai   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
print(df.loc[0, "Nama"])
print(df.iloc[1, 1])

# %% [markdown]
# DAY 3
# 1. Read CSV
# 2. Eksplorasi Data
#
#     df.info() → struktur kolom.
#
#     df.describe() → statistik ringkas.
#
#     df.shape → ukuran dataset.
# 3. Indexing & Slicing
#
#     loc → berdasarkan label.
#
#     iloc → berdasarkan posisi.
# 4. Groupby & Agregasi
#
#     Fungsi utama: groupby
#
#     Digabung dengan agregasi (mean, sum, count).
# 5. Study Kasus

# %%
import pandas as pd

penjualan = pd.read_csv("dataset/penjualan barang.csv")

penjualan.head()
# Out:
#    Unnamed: 0     tanggal nama.barang   kuantum
# 0           1  2020-05-29        GULA  100000.0
# 1           2  2020-07-07        GULA   97950.0
# 2           3  2020-07-16        GULA    2050.0
# 3           4  2020-11-12        GULA   14000.0
# 4           5  2020-12-24        GULA    8000.0

# %%
pemasukan = pd.read_csv("dataset/pemasukan barang.csv")
pemasukan.head()
# Out:
#    Unnamed: 0     tanggal nama.barang   kuantum
# 0           1  2020-05-29        GULA  100000.0
# 1           2  2020-07-07        GULA   97950.0
# 2           3  2020-07-16        GULA    2050.0
# 3           4  2020-11-12        GULA   14000.0
# 4           5  2020-12-24        GULA    8000.0

# %%
penjualan.describe()
# Out:
#         Unnamed: 0        kuantum       nominal
# count  1289.000000    1289.000000  1.289000e+03
# mean    645.000000    1735.063615  1.929970e+07
# std     372.246558    6300.788118  6.489967e+07
# min       1.000000       2.000000  4.600000e+04
# 25%     323.000000     140.000000  2.964000e+06
# 50%     645.000000     600.000000  7.650000e+06
# 75%     967.000000    1800.000000  1.890000e+07
# max    1289.000000  200000.000000  2.047000e+09

# %%
penjualan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1289 entries, 0 to 1288
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1289 non-null   int64
#  1   tanggal       1289 non-null   object
#  2   nama.pembeli  1289 non-null   object
#  3   nama.barang   1289 non-null   object
#  4   kuantum       1289 non-null   float64
#  5   nominal       1289 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 60.5+ KB

# %%
import matplotlib.pyplot as plt

penjualan["kuantum"].hist(bins=50, figsize=(8,5))
plt.title("Distribusi Kuantum")
plt.xlabel("Jumlah unit")
plt.ylabel("Frekuensi")
plt.show()

# %%
penjualan["nominal"].hist(bins=50, figsize=(8,5))
plt.title("Distribusi Nominal")
plt.xlabel("Nilai transaksi (Rp)")
plt.ylabel("Frekuensi")
plt.show()
